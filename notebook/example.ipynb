# %%
from collections import namedtuple

# %% [markdown]
# 1 : Download Url
# 2 : Download Folder(Compressed file)
# 3: Extract raw file(extracted file)
# 4 : Train dataset folder
# 5 : Test dataset folder

# %%
DataIngestionConfig = namedtuple("DataIngestionConfig",
["dataset_download_url","tgz_download_dir","raw_data_dir","ingested_train_dir","ingested_test_dir"])

# %%
data_ingestion_config = DataIngestionConfig(
    dataset_download_url="hewi",
    tgz_download_dir="hed",
    raw_data_dir="bfger",
    ingested_train_dir="dd",
    ingested_test_dir="dheiuhg"
    )

# %%
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='hewi', tgz_download_dir='hed', raw_data_dir='bfger', ingested_train_dir='dd', ingested_test_dir='dheiuhg')

# %%
import yaml

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\notebook'

# %%
os.chdir(r"C:\Users\Lenovo\Desktop\END-END-MACHINELEARNINGPROJECT\End-End-MachineLearning_Project")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\notebook'

# %%
os.listdir(".")
# Out:
# ['.dockerignore',
#  '.ebextensions',
#  '.git',
#  '.gitignore',
#  'application.py',
#  'config',
#  'Dockerfile',
#  'housing',
#  'housing_predictor.egg-info',
#  'LICENSE',
#  'notebook',
#  'README.md',
#  'requirements.txt',
#  'setup.py',
#  'venv']

# %%
config_file_path = os.path.join("config","config.yaml")
config_file_path
# Out:
# 'config\\config.yaml'

# %%
os.path.exists(config_file_path)
# Out:
# True

# %%
config_obj = None
with open(config_file_path,"rb") as yaml_file:
    config_obj = yaml.safe_load(yaml_file)

# %%
from housing.constant import *

# %%
training_pipeline_config = config_obj[TRAINING_PIPELINE_CONFIG_KEY]
artifact_dir  = os.path.join(ROOT_DIR,training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY])

# %%
artifact_dir
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact'

# %%
training_pipeline_config = config_obj[TRAINING_PIPELINE_CONFIG_KEY]

# %%
training_pipeline_config = config_obj[TRAINING_PIPELINE_CONFIG_KEY]
artifact_dir  = os.path.join(ROOT_DIR,training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5392\3984652428.py in <module>
#       1 training_pipeline_config = config_obj[TRAINING_PIPELINE_CONFIG_KEY]
# ----> 2 artifact_dir  = os.path.join(ROOT_DIR,training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR])
#       3
#
# KeyError: 'artifact'

# %%
from housing.config.configuration import Configuration
config = Configuration()
config.get_training_pipeline_config()
# Out:
# TrainingPipelineConfig(artifact_dir='C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact')
