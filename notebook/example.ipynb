# %%
from collections import namedtuple
import yaml

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\notebook'

# %%
os.chdir(r"C:\Users\Lenovo\Desktop\END-END-MACHINELEARNINGPROJECT\End-End-MachineLearning_Project")

# %%
config_file_path = os.path.join("config","config.yaml")
config_file_path
# Out:
# 'config\\config.yaml'

# %%
os.path.exists(config_file_path)
# Out:
# True

# %%
config_obj = None
with open(config_file_path,"rb") as yaml_file:
    config_obj = yaml.safe_load(yaml_file)

# %%
from housing.constant import *

# %%
training_pipeline_config = config_obj[TRAINING_PIPELINE_CONFIG_KEY]
artifact_dir  = os.path.join(ROOT_DIR,training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY])

# %%
artifact_dir
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact'

# %%
from housing.config.configuration import Configuration
config = Configuration()

# %%
OBJ = config_obj[DATA_INGESTION_CONFIG_KEY]
OBJ[DATA_INGESTION_RAW_DATA_DIR_KEY]
# Out:
# 'raw_data'

# %%
config.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact\\ingested_dir\\2023-03-23_16-46-09\\tgz_data', raw_data_dir='C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact\\ingested_dir\\2023-03-23_16-46-09\\raw_data', ingested_train_dir='C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact\\ingested_dir\\2023-03-23_16-46-09\\ingested_data\\train', ingested_test_dir='C:\\Users\\Lenovo\\Desktop\\END-END-MACHINELEARNINGPROJECT\\End-End-MachineLearning_Project\\housing\\artifact\\ingested_dir\\2023-03-23_16-46-09\\ingested_data\\test')
